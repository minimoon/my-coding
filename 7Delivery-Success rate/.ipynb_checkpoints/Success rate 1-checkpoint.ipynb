# %%
#1 read csv
#2 select remarks col
#3 url open
#4 collect link or scrape
#5 insert after remark
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
f = pd.ExcelFile('TH_7-eleven 14-18 Dec.xls')
f

# %%
seven_file = f.parse('Sheet1')
seven_file.head()
# Out:
#         creation_time             TH_time distance_source  passenger1_id  \
# 0 2016-12-14 06:24:09 2016-12-14 13:24:09     IPHONE2-POI        7066160
# 1 2016-12-14 07:21:47 2016-12-14 14:21:47    ANDROID2-POI        2247921
# 2 2016-12-14 07:31:22 2016-12-14 14:31:22    ANDROID2-POI         455541
# 3 2016-12-14 07:40:07 2016-12-14 14:40:07    ANDROID2-POI        6862205
# 4 2016-12-14 07:44:38 2016-12-14 14:44:38    ANDROID2-POI       12278436
#
#               passenger1_name  \
# 0  Wilaiwan Dhrammajariyapong
# 1                         Kai
# 2                         Tee
# 3                   Poyroi Ka
# 4                        Care
#
#                                              remarks      state
# 0  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED
# 1                                                NaN  COMPLETED
# 2  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED
# 3  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED
# 4                                                NaN  COMPLETED

# %%
seven_file.remarks.count()
# Out:
# 42

# %%
seven_file['TH_time'].head()
# Out:
# 0   2016-12-14 13:24:09
# 1   2016-12-14 14:21:47
# 2   2016-12-14 14:31:22
# 3   2016-12-14 14:40:07
# 4   2016-12-14 14:44:38
# Name: TH_time, dtype: datetime64[ns]

# %%
seven_file.remarks[2]
# Out:
# u'\u0e01\u0e23\u0e38\u0e13\u0e32\u0e41\u0e2a\u0e14\u0e07\u0e02\u0e49\u0e2d\u0e21\u0e39\u0e25\u0e43\u0e19\u0e25\u0e34\u0e07\u0e04\u0e4c\u0e19\u0e35\u0e49\u0e43\u0e2b\u0e49\u0e1e\u0e19\u0e31\u0e01\u0e07\u0e32\u0e19 7-Eleven. https://goo.gl/TNxAVM'

# %%
import urllib2

# %%
seven_file.remarks[2].split('7-Eleven. ')[1]
# Out:
# u'https://goo.gl/TNxAVM'

# %%
def readfile(n):
    f = urllib2.urlopen(seven_file.remarks[n].split('7-Eleven. ')[1])
    page = f.read()
    return page.split('<p>Order ID</p>\n      <h2>')[1].split('<')[0]

# %%
s =readfile(6)
print s
# Out:
# tHTEYDl7tS

# %% [markdown]
# if seven_file['remarks'].isnull:
#     print 'null'
# else:
#     print 'not null'

# %%
seven_file.head()
# Out:
#         creation_time             TH_time distance_source  passenger1_id  \
# 0 2016-12-14 06:24:09 2016-12-14 13:24:09     IPHONE2-POI        7066160
# 1 2016-12-14 07:21:47 2016-12-14 14:21:47    ANDROID2-POI        2247921
# 2 2016-12-14 07:31:22 2016-12-14 14:31:22    ANDROID2-POI         455541
# 3 2016-12-14 07:40:07 2016-12-14 14:40:07    ANDROID2-POI        6862205
# 4 2016-12-14 07:44:38 2016-12-14 14:44:38    ANDROID2-POI       12278436
#
#               passenger1_name  \
# 0  Wilaiwan Dhrammajariyapong
# 1                         Kai
# 2                         Tee
# 3                   Poyroi Ka
# 4                        Care
#
#                                              remarks      state
# 0  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED
#
รุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  tHTEYDl7tS
# 7   กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  mQsnmNn0a4
# 8   กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  XhbBV7Qhdp
# 9                                                   0  COMPLETED       error
# 10  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  ZePhpk9lLB
# 11  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  DLIamg8v1A
# 12                                                  0  COMPLETED       error
# 13                                                  0  COMPLETED       error
# 14                                                  0  COMPLETED       error
# 15                                                  0  COMPLETED       error
# 16  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  ODeCDSBrNH
# 17                                                  0  COMPLETED       error
# 18                                                  0  COMPLETED       error
# 19                                                  0  COMPLETED       error
# 20  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  05hsI9ksrc
# 21                                                  0  COMPLETED       error
# 22  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  8FGWHYitDD
# 23  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  UQziyUauWM
# 24                                                  0  COMPLETED       error
# 25                                                  0  COMPLETED       error
# 26  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  FJ4fLw3RE0
# 27                                                  0  COMPLETED       error
# 28                                                  0  COMPLETED       error
# 29                                                  0  COMPLETED       error
# ..                                                ...        ...         ...
# 54  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  7pUn1e4AGj
# 55                                           ส่งพัสดุ  COMPLETED       error
# 56                                                  0  COMPLETED       error
# 57                                                  0  COMPLETED       error
# 58                                                  0  COMPLETED       error
# 59                                       ฝากชื้อของ 7  COMPLETED       error
# 60                                                  0  COMPLETED       error
# 61                                                  0  COMPLETED       error
# 62                                                  0  COMPLETED       error
# 63                                                  0  COMPLETED       error
# 64  รับของจากพระราม 3ซอย 49 มาส่งที่ หัวหมาก 24แยก...  COMPLETED       error
# 65                                                  0  COMPLETED       error
# 66                                                  0  COMPLETED       error
# 67                                                  0  COMPLETED       error
# 68                                                  0  COMPLETED       error
# 69                                                  0  COMPLETED       error
# 70                                                  0  COMPLETED       error
# 71                                                  0  COMPLETED       error
# 72                                                  0  COMPLETED       error
# 73                                                  0  COMPLETED       error
# 74                                                  0  COMPLETED       error
# 75  รับที่ บ้านกลางเมือง รัชดา-ลาดพร้าว ↵ซ. 7 บ้าน...  COMPLETED       error
# 76  โค้กขวดใหญ่ ↵น้ำแข็ง 1 ถุง↵แก้วพลาสติก↵เลย์สีเ...  COMPLETED       error
# 77                                                  0  COMPLETED       error
# 78  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  99L51D2cPE
# 79                                                  0  COMPLETED       error
# 80                                                  0  COMPLETED       error
# 81  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  141Ud2K77N
# 82                                                  0  COMPLETED       error
# 83  กรุณาแสดงข้อมูลในลิงค์นี้ให้พนักงาน 7-Eleven. ...  COMPLETED  TYYryRMfAQ
#
# [84 rows x 8 columns]

# %%
seven_file.to_csv('seven_file.csv',sep=',',encoding='utf-8')

# %% [markdown]
# 	creation_time	TH_time	distance_source	passenger1_id	passenger1_name	remarks	state	link
# 0	12/14/2016 6:24	12/14/2016 13:24	IPHONE2-POI	7066160	Wilaiwan Dhrammajariyapong	เธเธฃเธธเธ“เธฒเนเธชเธ”เธเธเนเธญเธกเธนเธฅเนเธเธฅเธดเธเธเนเธเธตเนเนเธซเนเธเธเธฑเธเธเธฒเธ 7-Eleven. https://goo.gl/DDfl6O	COMPLETED	Oujdtytzbp
